# %% [markdown]
# # Pizza Sales Analysis

# %%
# import python libraries

# %%
# Import Excel file
df = pd.read_excel('C:/Users/admin/Downloads/pizza_sales.xlsx', engine='openpyxl')

# %%
# Check total rows & total columns
# Out:
# (48620, 13)

# %%
# Remove duplicate rows
# Out:
# DataFrame with duplicates removed:

# %%
#Check column names from data
# Out:
# Index(['pizza_id', 'order_id', 'pizza_name_id', 'quantity', 'order_date',
#        'Month', 'order_time', 'unit_price', 'total_price', 'pizza_size',
#        'pizza_category', 'pizza_ingredients', 'pizza_name'],
#       dtype='object')

# %%
# Get the total number of null values in the DataFrame
# Out:
# Total number of null values: 0

# %%
# Total Orders received : 21350
# total quantity sales : 48620
# total revenue : 817860.05

# %%
# Category wise total sale
# Out:
#   pizza_category  order_id
# 1        Classic     14579
# 2        Supreme     11777
# 3         Veggie     11449
# 0        Chicken     10815

# %%
# Month wise toal sale

# %%
#Category Wise % of Total Sale

# %%
# Top 5 Pizza names by Order Count

# %%
# Top 3 Pizza Size

# %%
# Monthly Sales Trend
